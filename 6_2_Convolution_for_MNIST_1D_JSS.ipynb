# %% [markdown]
# <a href="https://colab.research.google.com/github/christianmora-star/Modulo_4_Christian_Mora/blob/main/6_2_Convolution_for_MNIST_1D_JSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-dcwcq4gz
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-dcwcq4gz
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=d51e2d0c4b012977c54c3f201a8c9f96c4173678c04f17426ff42ad99d7bf674
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mit0wgjm/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
    # Entrada: (batch_size, 1, 40)

    nn.Conv1d(
        in_channels=1,
        out_channels=15,
        kernel_size=3,
        stride=2,
        padding=0
    ),
    nn.ReLU(),

    # Salida: (batch_size, 15, 19)

    nn.Conv1d(
        in_channels=15,
        out_channels=15,
        kernel_size=3,
        stride=2,
        padding=0
    ),
    nn.ReLU(),

    # Salida: (batch_size, 15, 9)

    nn.Conv1d(
        in_channels=15,
        out_channels=15,
        kernel_size=3,
        stride=2,
        padding=0
    ),
    nn.ReLU(),

    # Salida: (batch_size, 15, 4)

    nn.Flatten(),

    # 15 × 4 = 60
    nn.Linear(60, 10)
)


#esto es muy FULLy connected, tienes que cambiarla a Convolutional
#usa  nn.Convld y nn.ReLU para las capas convolacionales y nn.Flatten para aplanar la salida antes de la capa lineal final.

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 1.950697, training error 76.05, validation loss 1.968877, validation error 78.20
# Epoch     1, training loss 1.544187, training error 60.28, validation loss 1.563696, validation error 63.50
# Epoch     2, training loss 1.407009, training error 57.58, validation loss 1.411178, validation error 58.40
# Epoch     3, training loss 1.285011, training error 51.97, validation loss 1.288298, validation error 53.40
# Epoch     4, training loss 1.237462, training error 50.47, validation loss 1.251908, validation error 53.60
# Epoch     5, training loss 1.161773, training error 45.58, validation loss 1.169121, validation error 47.70
# Epoch     6, training loss 1.075647, training error 43.35, validation loss 1.105014, validation error 45.00
# Epoch     7, training loss 0.988505, training error 38.35, validation loss 1.001890, validation error 39.00
# Epoch     8, training loss 0.891685, training error 35.15, validation loss 0.924700, validation error 37.70
# Epoch     9, training loss 0.796240, training error 30.65, validation loss 0.834933, validation error 32.80
# Epoch    10, training loss 0.771250, training error 31.32, validation loss 0.818487, validation error 33.10
# Epoch    11, training loss 0.683653, training error 27.15, validation loss 0.750782, validation error 29.70
# Epoch    12, training loss 0.640424, training error 24.00, validation loss 0.707585, validation error 26.80
# Epoch    13, training loss 0.640409, training error 25.43, validation loss 0.718005, validation error 28.70
# Epoch    14, training loss 0.545684, training error 21.20, validation loss 0.642935, validation error 25.00
# Epoch    15, training loss 0.585879, training error 23.38, validation loss 0.663304, validation error 27.20
# Epoch    16, training loss 0.466277, training error 18.00, validation loss 0.571306, validation error 22.10
# Epoch    17, training loss 0.425157, training error 15.78, validation loss 0.540300, validation error 20.50
# Epoch    18, training loss 0.415157, training error 15.75, validation loss 0.550114, validation error 21.80
# Epoch    19, training loss 0.374600, training error 14.88, validation loss 0.514934, validation error 18.90
# Epoch    20, training loss 0.307590, training error 11.78, validation loss 0.474135, validation error 16.10
# Epoch    21, training loss 0.314537, training error 12.10, validation loss 0.486541, validation error 17.40
# Epoch    22, training loss 0.273675, training error 9.47, validation loss 0.445147, validation error 14.70
# Epoch    23, training loss 0.264292, training error 9.90, validation loss 0.472068, validation error 17.10
# Epoch    24, training loss 0.273822, training error 10.32, validation loss 0.455110, validation error 16.40
# Epoch    25, training loss 0.228884, training error 7.78, validation loss 0.427116, validation error 14.10
# Epoch    26, training loss 0.223938, training error 7.65, validation loss 0.441261, validation error 14.50
# Epoch    27, training loss 0.209853, training error 7.80, validation loss 0.458529, validation error 15.30
# Epoch    28, training loss 0.282181, training error 9.85, validation loss 0.550909, validation error 17.10
# Epoch    29, training loss 0.252052, training error 9.20, validation loss 0.493023, validation error 15.60
# Epoch    30, training loss 0.199123, training error 7.57, validation loss 0.456595, validation error 14.00
# Epoch    31, training loss 0.189885, training error 6.97, validation loss 0.455399, validation error 14.80
# Epoch    32, training loss 0.202286, training error 7.18, validation loss 0.465706, validation error 13.70
# Epoch    33, training loss 0.163938, training error 5.80, validation loss 0.469085, validation error 13.40
# Epoch    34, training loss 0.150549, training error 4.90, validation loss 0.425880, validation error 12.60
# Epoch    35, training loss 0.188971, training error 7.25, validation loss 0.468268, validation error 15.00
# Epoch    36, training loss 0.154343, training error 5.18, validation loss 0.439562, validation error 12.30
# Epoch    37, training loss 0.151321, training error 5.32, validation loss 0.422110, validation error 12.60
# Epoch    38, training loss 0.141139, training error 5.12, validation loss 0.421314, validation error 12.50
# Epoch    39, training loss 0.123150, training error 4.47, validation loss 0.423097, validation error 12.10
# Epoch    40, training loss 0.112109, training error 3.65, validation loss 0.411824, validation error 12.60
# Epoch    41, training loss 0.110557, training error 3.50, validation loss 0.438728, validation error 12.90
# Epoch    42, training loss 0.104594, training error 3.53, validation loss 0.419386, validation error 12.40
# Epoch    43, training loss 0.096764, training error 3.22, validation loss 0.422342, validation error 12.60
# Epoch    44, training loss 0.096049, training error 3.10, validation loss 0.433832, validation error 11.30
# Epoch    45, training loss 0.094425, training error 2.90, validation loss 0.419583, validation error 11.80
# Epoch    46, training loss 0.094994, training error 3.03, validation loss 0.440993, validation error 11.70
# Epoch    47, training loss 0.086004, training error 2.68, validation loss 0.444352, validation error 12.20
# Epoch    48, training loss 0.083292, training error 2.62, validation loss 0.442353, validation error 12.40
# Epoch    49, training loss 0.083785, training error 2.43, validation loss 0.432522, validation error 11.10
# Epoch    50, training loss 0.076929, training error 2.43, validation loss 0.445871, validation error 11.70
# Epoch    51, training loss 0.078952, training error 2.35, validation loss 0.441291, validation error 12.50
# Epoch    52, training loss 0.075834, training error 2.25, validation loss 0.450582, validation error 12.00
# Epoch    53, training loss 0.077228, training error 2.25, validation loss 0.453633, validation error 12.10
# Epoch    54, training loss 0.081502, training error 2.62, validation loss 0.458862, validation error 11.60
# Epoch    55, training loss 0.080707, training error 3.18, validation loss 0.453444, validation error 11.80
# Epoch    56, training loss 0.067059, training error 2.05, validation loss 0.445569, validation error 11.50
# Epoch    57, training loss 0.065685, training error 1.75, validation loss 0.437562, validation error 11.80
# Epoch    58, training loss 0.071715, training error 2.22, validation loss 0.469521, validation error 11.70
# Epoch    59, training loss 0.064226, training error 1.82, validation loss 0.439899, validation error 11.10
# Epoch    60, training loss 0.058079, training error 1.38, validation loss 0.452495, validation error 11.60
# Epoch    61, training loss 0.056712, training error 1.50, validation loss 0.463845, validation error 11.80
# Epoch    62, training loss 0.057409, training error 1.62, validation loss 0.456833, validation error 11.80
# Epoch    63, training loss 0.056416, training error 1.40, validation loss 0.459346, validation error 11.90
# Epoch    64, training loss 0.057996, training error 1.88, validation loss 0.465416, validation error 11.90
# Epoch    65, training loss 0.055075, training error 1.60, validation loss 0.467653, validation error 11.10
# Epoch    66, training loss 0.053566, training error 1.20, validation loss 0.461794, validation error 11.30
# Epoch    67, training loss 0.052692, training error 1.30, validation loss 0.468894, validation error 11.70
# Epoch    68, training loss 0.055384, training error 1.72, validation loss 0.475451, validation error 11.30
# Epoch    69, training loss 0.052264, training error 1.15, validation loss 0.474742, validation error 11.40
# Epoch    70, training loss 0.052167, training error 1.22, validation loss 0.469555, validation error 11.30
# Epoch    71, training loss 0.050098, training error 1.05, validation loss 0.470584, validation error 11.70
# Epoch    72, training loss 0.051656, training error 1.30, validation loss 0.473635, validation error 11.90
# Epoch    73, training loss 0.051134, training error 1.25, validation loss 0.479781, validation error 11.60
# Epoch    74, training loss 0.048277, training error 1.22, validation loss 0.469044, validation error 10.90
# Epoch    75, training loss 0.049030, training error 1.35, validation loss 0.474240, validation error 11.40
# Epoch    76, training loss 0.049481, training error 1.35, validation loss 0.475391, validation error 11.50
# Epoch    77, training loss 0.047105, training error 1.05, validation loss 0.486927, validation error 11.30
# Epoch    78, training loss 0.046450, training error 1.05, validation loss 0.466928, validation error 10.90
# Epoch    79, training loss 0.045209, training error 1.07, validation loss 0.471208, validation error 11.40
# Epoch    80, training loss 0.044591, training error 1.00, validation loss 0.477933, validation error 11.20
# Epoch    81, training loss 0.043822, training error 0.95, validation loss 0.477691, validation error 11.10
# Epoch    82, training loss 0.043085, training error 0.85, validation loss 0.479424, validation error 11.30
# Epoch    83, training loss 0.042724, training error 0.88, validation loss 0.482447, validation error 11.20
# Epoch    84, training loss 0.042424, training error 0.85, validation loss 0.483724, validation error 11.20
# Epoch    85, training loss 0.042983, training error 0.93, validation loss 0.485922, validation error 11.40
# Epoch    86, training loss 0.041938, training error 0.88, validation loss 0.488183, validation error 11.20
# Epoch    87, training loss 0.042377, training error 0.93, validation loss 0.493076, validation error 11.10
# Epoch    88, training loss 0.041432, training error 0.82, validation loss 0.486133, validation error 11.20
# Epoch    89, training loss 0.041472, training error 0.88, validation loss 0.486284, validation error 11.10
# Epoch    90, training loss 0.041330, training error 0.78, validation loss 0.486014, validation error 11.00
# Epoch    91, training loss 0.040706, training error 0.82, validation loss 0.488254, validation error 11.10
# Epoch    92, training loss 0.041153, training error 0.88, validation loss 0.494227, validation error 11.50
# Epoch    93, training loss 0.041883, training error 0.97, validation loss 0.499773, validation error 11.40
# Epoch    94, training loss 0.040024, training error 0.75, validation loss 0.489757, validation error 11.00
# Epoch    95, training loss 0.040183, training error 0.90, validation loss 0.494369, validation error 11.00
# Epoch    96, training loss 0.039440, training error 0.85, validation loss 0.490670, validation error 11.00
# Epoch    97, training loss 0.039279, training error 0.85, validation loss 0.492521, validation error 10.80
# Epoch    98, training loss 0.040587, training error 1.00, validation loss 0.496409, validation error 11.20
# Epoch    99, training loss 0.039713, training error 0.90, validation loss 0.491685, validation error 11.20
